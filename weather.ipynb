# %% [markdown]
# # **<span style="color:blue">Introduction</span>**
# ***
#
# This notebook contains a brief report/explanation of how I completed my tasks and and also a written outline of the completion of my Project which are required for the completion of Module *Computer Infrastructure 2024*.
#
# I have used code which was provided throughout lectures by my lecturer [Ian McLoughlin](https://atlantictu-my.sharepoint.com/personal/ian_mcloughlin_atu_ie/_layouts/15/onedrive.aspx?id=%2Fpersonal%2Fian%5Fmcloughlin%5Fatu%5Fie%2FDocuments%2Fstudent%5Fshares%2Fcomputer%5Finfrastructure&ga=1). I have also referenced all other sources that I have used for any other code I have adapted and any other research I have done throughout the notebook. These references are also provided in the references section at the end of this notebook.
#
# Throughout this notebook, I use the terms **command line interface**, **command line** and **terminal** interchangeably.
#
# Before commencing, I have first imported any Libraries that I will need for the successful running and completion of the notebook.

# %% [markdown]
# </br>
#
# ## <span style="color:blue">Importing Libraries</span>
# ***
#
# Using a *code* cell below, I have imported all of the relevant Libraries. Libraries are a collection of modules which are bundles of code that can be used again and again. This makes programming easier as the code doesn't need to be written out by the programmer as they are already available [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/libraries-in-python/)<sup>1</sup>. Importing all of the libraries at the beginning of the notebook ensures that all of the code throughout the notebook runs smoothly and no errors are thrown.

# %%
# Importing Libraries

# For working With DataFrames
import pandas as pd

# Plotting data 
import matplotlib.pyplot as plt 

# Plotting data
import seaborn as sns

# %% [markdown]
# ## <span style="color:blue">**Task 1: Create Directory Structure**</span>
# > *Using the command line, create a directory (that is, a folder) named `data` at the root of your repository. Inside `data`, create two subdirectories: `timestamps` and `weather`.*
# ***

# %% [markdown]
# ### <ins><span style="color:blue">Creating the Directory Structure</ins></span>
#
# In the root of my repository titled [computer_infrastructure_2024](https://github.com/OCorry/computer_infrastructure_2024), on the Linux command line, I have created a directory (folder) called [data](https://github.com/OCorry/computer_infrastructure_2024/tree/main/data) and within that data directory I have created two subdirectories called [timestamps](https://github.com/OCorry/computer_infrastructure_2024/tree/main/data/timestamps) and [weather](https://github.com/OCorry/computer_infrastructure_2024/tree/main/data/weather).
#
# To do this, I have adapted code from [Sandra Henry Stocker, (2023)](https://www.networkworld.com/article/971782/creating-and-removing-directory-structures-on-linux.html#:~:text=Each%20group%20of%20directory%20names,being%20created%20at%20that%20level.&text=You%20can%20add%20as%20many,specifications%20to%20the%20mkdir%20command.)<sup>2</sup> and used the command:
#
# <br>
#
# ~~~bash
# mkdir -pv data/{timestamps,weather}
# ~~~
# <br>
# <br>
#
# The use of the `-p` after the `mkdir` allowed me to create the [hierarchy](https://en.wikipedia.org/wiki/Hierarchical_file_system)<sup>3</sup> of the parent directory **data** and the the two subdirectories **timestamps** and **weather** all at once rather than having to create the **data** directory first and then create the two subdirectories within it. This is a much more efficient approach, particularly if one is creating a large hierarchy of subdirectories nested within other directories. The `-v` is a verbose option which means that the directories that have been created will display in the terminal so the user can see the directories were created correctly.
#
# I sourced code from [Zaira Hira, FreeCodeCamp (2023)](https://www.freecodecamp.org/news/diagrams-as-code-with-mermaid-github-and-vs-code/)<sup>4</sup>, [jojozhuang](https://jojozhuang.github.io/tutorial/mermaid-cheat-sheet/)<sup>5</sup>, [marketplace.visualstudio](https://marketplace.visualstudio.com/items?itemName=CatBraaain.mermaid-comment#:~:text=Comment%20with%20%60%25%25%60%20for,lines%2C%20with%20a%20single%20command.&text=Launch%20VS%20Code%20Quick%20Open,following%20command%2C%20and%20press%20enter)<sup>6</sup> and [github.com (2015)](https://github.com/mermaid-js/mermaid/issues/213)<sup>7</sup> to create a visual representation of a hierarchy of directories and files. This visual representation can be found by clicking [**this link**](img/directory_hierarchy.md). The root directory **A** is the top-most tier of the of the hierarchy and is denoted by a `/` [Wikipedia, (2024)](https://en.wikipedia.org/wiki/Root_directory)<sup>8</sup>. From the root directory then, stems directory **B** and directory **C** which are subdirectories of the root directory **A**. Directory **B** & **C** are parent directories to directory **D** & **E** respectively but also contain files **A** & **B** respectively. Directories **D** & **E** are subdirectories of **B** & **C** respectively. Directory **D** contains two files called file **C** & file **D**. Directory **E** contains one file called file **E**.

# %% [markdown]
#   ### <ins><span style="color:blue">Pushing the Directory Structure to Github</ins><span>
#
#  When it came to committing my changes to my Github repository and pushing them to Github, my changes would not push. This is because Git only tracks files and does not track empty directories [Foster. G (2024)](https://graphite.dev/guides/add-empty-dir)<sup>9</sup>, [GeeksforGeeks (2023)](https://www.geeksforgeeks.org/how-to-add-an-empty-directory-to-a-git-repository/)<sup>10</sup>. As a result, if a directory is created and a file is not inputted into it, the directory will just be ignored and it will not push up to GitHub.
#
#  To overcome this, I found that creating a `.gitkeep` file in the `timestamps` and `weather` directories [Parr. K (2021)](https://www.freecodecamp.org/news/what-is-gitkeep/)<sup>11</sup> would allow me to push my changes up to my GitHub repository. I have used `touch .gitkeep` command to create a `.gitkeep` file in each of the directories [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/touch-command-in-linux-with-examples/#1-how-to-create-an-empty-files-by-using-touch-command-in-linux)<sup>12</sup>. This is just a temporary measure simply to allow me to complete *Task 1*. Later, I remove these files from the directories again once I have added other permanent files to them in following tasks. I will remove the temporary files by using the `rm .gitkeep` command [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/rm-command-linux-examples/)<sup>13</sup>.

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">**Task 2: Timestamps**</span>
# > *Navigate to the `data/timestamps` directory. Use the `date` command to output the current date and time, appending the output to a file named `now.txt`. Make sure to use the `>>` operator to append (not overwrite) the file. Repeat this step ten times, then use the `more` command to verify that `now.txt` has the expected content.*
# ***

# %% [markdown]
# ### <ins><span style="color:blue">Navigating through the Directory Hierarchy</ins></span>
#
# In *Task 1*, I briefly outlined the process of creating a new file `.gitkeep` in my two directories; `timestamps` & `weather` but didn't go into detail as to how I navigated through the directory hierarchy to find myself in said directories. Below, I explain how I have navigated through the directories using the Linux [Command Line Interface](https://en.wikipedia.org/wiki/Command-line_interface)<sup>14</sup>.
#
# The `cd` ([change directory](https://www.geeksforgeeks.org/cd-command-in-linux-with-examples/)) command is used to move up and down the directory hierarchy. In the root directory (workspaces/computer_infrastructure_2024), on the command line interface (or terminal), I enter `cd data/timestamps/`to move into the `timestamps` directory.
#
# ### <ins><span style="color:blue">The `date` command</ins></span>
#
# Once navigated into the `timestamps` directory and `weather` is now my present working directory (pwd), on the command line interface, I have used the [date](https://www.geeksforgeeks.org/date-command-linux-examples/)<sup>15</sup> command to print the current date and time on the command line. This prints the date and time in the format: abbreviated day, abbreviated month name, then day of the month and the current time. For example `Mon Nov 20 21:37:51 UTC 2024`. The output also states that the time is [UTC](https://en.wikipedia.org/wiki/Coordinated_Universal_Time)<sup>16</sup>.
#
# ### <ins><span style="color:blue"> Appending the output of the `date` command to a new file `now.txt`</ins></span>
# Rather than just printing the output of the `date` command in the command line, I have used the command `date >> now.txt` to append the output of the `date` command to the file `now.txt`. The `date` part of the command generates the date and time and the append redirect operator `>>` redirects the output of the `date` command into a new file called `now.txt`. If the `now.txt` file doesn't already exist, the command creates the new file. I have repeated this command 10 times in total and the 10 outputs are saved to the `now.txt` file. It is very important to use the `>>` here rather than a single redirect operator `>`. If the `>` is used, then it will overwrite all of the data that was in the file prior to running the command with the `>` operator [Damon Garn (2021)](https://www.redhat.com/en/blog/redirect-operators-bash#:~:text=The%20append%20%3E%3E%20operator%20adds%20the,uname%20%2Dr%20to%20the%20specifications.)<sup>17</sup>.
#
# ### <ins><span style="color:blue">The `more` command</ins></span>
# To check that the `now.txt` file has the expected content of 10 time and date outputs, I have used the command `more now.txt` on the command line. This command shows the contents of the file in the command line. The `more` command filters through the file one screen full at a time. If the file is a lengthy one, pressing the space bar on the keyboard will open the next screen of content. The amount of content per screen is dependent on how big the user has made their command line interface [GeeksforGeeks](https://www.geeksforgeeks.org/more-command-in-linux-with-examples/)<sup>18</sup>.

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">**Task 3: Formatting Timestamps**</span>
# > *Run the date command again, but this time format the output using YYYYmmdd_HHMMSS (e.g., 20261114_130003 for 1:00:03 PM on November 14, 2026). Refer to the date man page (using man date) for more formatting options. (Press q to exit the man page). Append the formatted output to a file named formatted.txt.*
# ***

# %% [markdown]
# The aim of this task aims to run the same `date` command that was run in *Task 2* but this time applying specified format to the command and saving this in a new file called `formatted.txt`. The format will be in the form of **YYYYmmdd_HHMMSS**.
#
# ### <ins><span style="color:blue">Applying the Format Specifier</ins></span>
#
# To create this specified output the command I have used is `date +"%Y%m%d_%H%M%S"`. The output of the command would be for example `20241119_212332` where in this example the `%Y` is replaced by the current year (2024), the `%m` is replaced by the current month (11), `%d` with the current date (19), `%H` with the current hour (21hrs), `%M` with the current minute (23) and `%S` with the current second (32). The `_` remains as it is because this is just a separator to make the output easier to interpret [phoenixNap Global Services (2024)](https://phoenixnap.com/kb/linux-date-command)<sup>19</sup>. While this date format is not ideal for humans to read, it is a much better format for computers to read than that of the output in *Task 2*.
#
# Further detail on *formatting* and *options* for the `date` command can be found by simply inputting the command `man date` in the command line.
#
#
# ### <ins><span style="color:blue">Appending the output to a new file called `formatted.txt`</ins></span>
# Like above in *Task 2*, appending the output of the command to a file has been achieved by using the redirect operator `>>`. The full command for this is as follows:
#
# <br>
#
# ~~~bash
# date +"%Y%m%d_%H%M%S" >> formatted.txt
# ~~~
# <br>
# <br>
#
# If the new filename `formatted.txt` does not already exist in the current working directory (`data/timestamps`), then the redirect operator creates a new file with the name `formatted.txt` and appends the current date and time to this file in the format **YYYYmmdd_HHMMSS**. Each time this command is run, the current date and time will be added to the file.
#
# Again, it is important use the double redirect operator `>>` rather than a single redirect operator `>` if the user is looking to append to a file. If the `>` is used then all of the data already contained in the file will be overwritten with the latest command.

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">**Task 4: Create Timestamped Files**</span>
# >*Use the touch command to create an empty file with a name in the YYYYmmdd_HHMMSS.txt format. You can achieve this by embedding your date command in backticks ` into the touch command. You should no longer use redirection (>>) in this step.*
# ***

# %% [markdown]
# The goal of this task is to create a new `.txt` file within the `/date/timestamps` directory. However, rather than appending the output of the `formatted date` command into the file, this time the output of the `formatted date (date +"%Y%m%d_%H%M%S")` command is used to give the new file a name that is the current timestamp.
#
# ### <ins><span style="color:blue">The `touch` command & the `Command Substitution Operator`<ins></span>
#
# The `touch` command is used to create a new empty file in Linux [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/touch-command-in-linux-with-examples/)<sup>20</sup>. The `touch` command is used along with the `formatted date` command to create the new file with a timestamped name as follows:
#
# <br>
#
# ~~~bash
# touch `date +"%Y%m%d_%H%M%S"`
# ~~~
# <br>
# <br>
#
# As the `touch` command is in front of `formatted date` command, the `formatted date` command is placed within the ``backticks operator`` and becomes: `` `date +"%Y%m%d_%H%M%S"` ``. The process of putting the command inside of the backticks is known as **command substitution**. This means that the output of the command within the backticks (in this case: `` `date +"%Y%m%d_%H%M%S"` ``) replaces the command itself [geeksforgeeks (2022)](https://www.geeksforgeeks.org/shell-scripting-command-substitution/)<sup>21</sup>, [Linux Leech (2014)](https://www.youtube.com/watch?v=VOOeXV4HYSA)<sup>22</sup> and subsequently, the output of the command is used as an argument or parameter for another command (in this case the `touch` command).
#
# ### <ins><span style="color:blue">Adding the **.txt** file extension</ins></span>
#
# The new file has to be given a file extension `.txt`, so after the `` `date +"%Y%m%d_%H%M%S"` `` command (but still within the backticks), a file extension `.txt` is added to the command. So now the full command to create the file with a timestamped name is:
#
# <br>
#
# ~~~bash
# touch `date +"%Y%m%d_%H%M%S".txt`
# ~~~
# <br>
# <br>
#
# ### <ins><span style="color:blue">An alternative to using `backticks(``)` around the `date` command</ins></span>
#
# While carrying out my research, I found an alternative to using the backticks is to use `$parentheses` `$()`. Using this option, the command within the parentheses is run first and then the output of that command is used as an argument for the other command. [stackoverflow (2014)](https://stackoverflow.com/questions/9405478/command-substitution-backticks-or-dollar-sign-paren-enclosed)<sup>23</sup> and [Roberto Nozaki (2021)](https://www.redhat.com/en/blog/backtick-operator-vs-parens)<sup>24</sup>. According to these sources, the `$parenthese` is preferred to the `backtick operator`
#
# Using the following command would give the same result as above, ie: creating a new `.txt` file with a timestamped name.
#
# <br>
#
# ~~~bash
# touch $(date +"%Y%m%d_%H%M%S.txt")
# ~~~

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">**Task 5: Download Today's Weather Data**</span>
#
# > *Change to the data/weather directory. Download the latest weather data for the Athenry weather station from Met Eireann using wget. Use the -O <filename> option to save the file as weather.json. The data can be found at this URL: https://prodapi.metweb.ie/observations/athenry/today.*
# ***

# %% [markdown]
# This task aims to download the latest weather data from Met Éireann for a specific area. The URL used for this **https://prodapi.metweb.ie/observations/athenry/today**<sup>25</sup> looks similar to a normal website URL. However, it contains an API (Application Programming Interface) which allows the user to download the data using the command line interface.
#
# ### <ins><span style="color:blue">What is an API</ins></span>
# Before commencing this task, I got more of an insight into APIs and how they work from [Codú](https://www.youtube.com/watch?v=Td0nwrNzVv4)<sup>26</sup> and [Exponent](https://www.youtube.com/watch?v=bxuYDT-BWaI)<sup>27</sup>.
#
# An API is a way for applications or systems to communicate and share data or software to other applications or systems. They allow a user to interact with databases or other systems or applications. The data or information exchanged between the user and the server as part of the API call is known as *payload* and the main two formats in which the data is returned to the user are either by JSON (Javascript Object Notation) or XML (Extensible Markup Language) [atatus (2023)](https://www.atatus.com/blog/guide-to-api-data-formats-json-xml-plain-text-and-binary/)<sup>28</sup>.
#
# APIs restrict the amount of data that is made available to the system requesting the data for security reasons.
#
# The user requests the information via the API which is part of a [URL(Uniform Resource Locator)](https://en.wikipedia.org/wiki/URL)<sup>29</sup> and is typically requested through an application called HTTP [(Hypertext Transfer Protocol)](https://www.cloudflare.com/learning/ddos/glossary/hypertext-transfer-protocol-http/)<sup>30</sup>. HTTP uses a [protocol](https://www.cloudflare.com/learning/network-layer/what-is-a-protocol/)<sup>31</sup> or a set of rules used for transferring information/data from system to system. Most HTTP applications now have an **S** at the end which is an extension to ensure a secure communication when transferring the information and data [Wikipedia (2024)](https://en.wikipedia.org/wiki/HTTPS#:~:text=This%20is%20the%20latest%20accepted,Hypertext%20Transfer%20Protocol%20(HTTP).)<sup>32</sup>. The API response then is returned to the user with the desired information/data, if the request from the user is successful. All of this process is done behind the scenes which is known as abstraction [trai.ai (2024)](https://tray.ai/blog/how-do-apis-work)<sup>33</sup>.
#
# Sometimes, a users' request may not be successful. The most common error would be if the URL was incorrect or the page had been moved or deleted. In this case, HTTP would throw an error code *404 Not Found* [w3schools](https://www.w3schools.com/tags/ref_httpmessages.asp)<sup>34</sup>.
#
# Some APIs require user authorisation or authentication to access it for the security and privacy of data [Postman (2024)](https://www.postman.com/api-platform/api-authentication/#:~:text=There%20are%20many%20types%20of,the%20API%20is%20not%20misused.)<sup>35</sup>, [frontegg (2023)](https://frontegg.com/guides/api-authentication-api-authorization#:~:text=Data%20security%3A%20By%20requiring%20authentication,access%2C%20theft%2C%20or%20misuse.)<sup>36</sup>. If the user does not have authorisation or authentication, the API response comes back with an error *401 Unauthorized* or *403 Forbidden* [mdn web docs_](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status)<sup>37</sup>.
#
# Having learned more about what an API is and how it works, I have carried out the task as follows:

# %% [markdown]
# ### <ins><span style="color:blue">Changing to the `data/weather/` directory</ins></span>
#
# Firstly, using the `cd` (change directory) command [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/cd-command-in-linux-with-examples/)<sup>38</sup>, I have navigated from the **root** of my repository to the `data/weather/` directory:
#
# <br>
#
# ~~~bash
# cd data/weather/
# ~~~
# <br>
# <br>
#
# The above command brings me straight into the `weather` subdirectory within the `data` directory.
#
# However, if for example, I was in the `data/timestamps` directory and wanted to navigate to the `data/weather` directory, I firstly would have to move up to the parent directory `data` using the following command:
#
# <br>
#
# ~~~bash
# cd ..
# ~~~
# <br>
# <br>
#
# Then once in the `data` directory, I would use the following command to navigate into the subdirectory `weather`:
#
# <br>
#
# ~~~bash
# cd weather
# ~~~
# <br>
# <br>
#
# ### <ins><span style="color:blue">Downloading the data using the `wget`</ins></span>
# In the `weather` directory, I have used the `wget` command to download the data from the API. The `wget` command is a non-interactive downloader which allows the user to download files from a server even when the user is not logged on to the system and it can can also work away in the background [GeeksforGeeks(2024)](https://www.geeksforgeeks.org/wget-command-in-linux-unix/)<sup>39</sup>.
#
#
# The basic `wget` command to download the weather data from the Athenry weather station is:
#
# <br>
#
# ~~~bash
# wget https://prodapi.metweb.ie/observations/athenry/today
# ~~~
# <br>
# <br>
#
# Using the above command, the data is downloaded into the present working directory, `weather` and the data is in [JSON](https://www.w3schools.com/js/js_json_syntax.asp)<sup>40</sup> format. JSON is a list or an array of data which is denoted by square brackets. Inside the square brackets, there are curly braces which denote objects or dictionaries. Within the curly braces, there are "name:value" pairs and each of these is separated by a comma. The JSON data is outputted in the file on one single line which is not very easy for humans to read. To change the format of this to make is easier to read, the user can type `format document` in the command pallet in VS code and this will display the data vertically [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/how-to-format-json-in-vscode/)<sup>41</sup>, dictionary by dictionary. The file is saved with a default name of *today* as this is the endpoint of the API. This is not the best name for the file, as when the command is run numerous times in the present working directory, the new files will save the files as *today1*, *today2* and so on.
#
# ### <ins><span style="color:blue">Output that is sent to the command line</ins></span>
# While the data is saved in a file called `today` in the `weather` directory, more information on the status of the request by the user is also outputted in the terminal by default. Below, is an example of the information outputted to the terminal:
#
# <img src="img/wget.png" alt="Output of wget command" width="1000">
#
# The above output shows the process taken by the `wget` command to request the data from the Met Éireann website and shows the IP address of the API being used. A successful connection is made with the the source of the data which is confirmed by the [200 OK](https://www.w3schools.com/tags/ref_httpmessages.asp)<sup>42</sup> HTTP response code.
#
# <span style="color:red">**Note:**</span> Running `man wget` command in the command line opens up the manual on the `wget` command to get more information on options available that can be used on it.

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">**Task 6: Timestamp the Data**</span>
# >*Modify the command from Task 5 to save the downloaded file with a timestamped name in the format YYYYmmdd_HHMMSS.json.*
# ***

# %% [markdown]
# ### <ins><span style="color:blue">Giving the new JSON data file a timestamped name</ins></span>
# As I mentioned in *Task 5* above, the new file containing the weather data (in JSON format) is saved with a name *today* by default using the `wget` command as this is the endpoint of the API and `wget` saves the file using the file name on the server. In this task, I have adapted the code above so that when the file is created, the name it is given is a timestamp.
#
# Below shows the complete command used to download the data using `wget -O` command on Met Éireann's API and to save is as a `.json` file. The `-O` is added to the `wget`command to allow the user to rename the file [Mucuho. C & Lee. R. (2021)](https://www.digitalocean.com/community/tutorials/how-to-use-wget-to-download-files-and-interact-with-rest-apis)<sup>43</sup>. It is important to use an uppercase `O` here rather than a lowercase `o` because a lower case `o` has a completely different purpose with the `wget` command. A lowercase `o` will send any system messages such as errors to a `logfile`[GeeksforGeeks (2024)](https://www.geeksforgeeks.org/wget-command-in-linux-unix/)<sup>44</sup>.
#
# As the data is for a specific area called Athenry, I have also added `_athenry` to the filename and as the data is in JSON format, I have added a `.json` filename extension.
#
# <br>
#
# ~~~bash
# wget -O `date +"%Y%m%d_%H%M%S_athenry.json"` https://prodapi.metweb.ie/observations/athenry/today
# ~~~
# **or**
# ~~~bash
# wget -O $(date +"%Y%m%d_%H%M%S_athenry.json") https://prodapi.metweb.ie/observations/athenry/today
# ~~~
# <br>
# <br>
#
# Again, similar to *Task 4* above, the `date +"%Y%m%d_%H%M%S_athenry.json"` command must be surrounded by either `backticks (``)` or `$Parentheses $()`so that the date command is run first. The output of the date command is then inputted to the the `-O` command which along with `wget` command, outputs the data from the API into a timestamped named file with a `.json` file extension.
#
# Giving the files a timestamped name means that if the command is run several times in the same working directory, the files save in the order of time they were executed (which corresponds to being in alphabetical order). The first run file is at the start (or at the top) of the list of downloads and the last run file is at the end (or the bottom). This is because the timestamped file starts with the year which is the biggest magnitude and decreases in magnitude as it goes through the month, day, hour, minute and second. So in other words, the files are ordered in a nested manner, firstly ordered by year, then by month, then by day and so on. This makes for easier sourcing of files and also makes it easier when analysing the data within the timestamped files.

# %% [markdown]
# ### <ins><span style="color:blue">`cURL` - an alternative to the `wget` command</ins></span>
# The `cURL`(Client URL) [joshtronic & Hogan.B (2021)](https://www.digitalocean.com/community/tutorials/workflow-downloading-files-curl)<sup>45</sup> command is an alternative command to the `wget` which can also be run on the command line interface to download files.
#
# `cURL` is a much larger scale option to `wget` and more tasks can be carried out on it. It supports **HTTP** and **FTP** like `wget` but also supports many other protocols [Ludosanu.R (2024)](https://www.warp.dev/terminus/curl-vs-wget)<sup>46</sup>.
#
# Similar to the `wget` command, using the `curl -o` command allows the user to rename the downloaded file via the API to their own desired name using either `backticks (``)` or `$Parentheses` `$()` around the full `date` command as follows:
#
# <br>
#
# ~~~bash
# curl  -o `date +"%Y%m%d_%H%M%S_athenry.json"` https://prodapi.metweb.ie/observations/athenry/today
# ~~~
#
# **or**
#
# ~~~bash
# curl -o $(date +"%Y%m%d_%H%M%S_athenry.json") https://prodapi.metweb.ie/observations/athenry/today
# ~~~
# <br>
# <br>
#
# Unlike the `wget` command, the `cURL` command needs a lowercase `o` rather than an uppercase `O` when downloading data and saving it into a timestamped file. If a uppercase `O` is used in the `cURL`command, then `cURL` will save the file with the endpoint name from the URL [Pelakauskas. A (2024)](https://oxylabs.io/blog/curl-download-file)<sup>47</sup>, [Hogan. B (2021)](https://www.digitalocean.com/community/tutorials/workflow-downloading-files-curl)<sup>48</sup>.
#
#
# Also, unlike `wget`, with `curl` the user can output the data from the request directly to the terminal using the command `curl [<URL>]` the following command prints Met Éireann's data for Athenry for today directly to the terminal and <ins>not</ins> to the present working directory.
#
# <br>
#
# ~~~bash
# curl https://prodapi.metweb.ie/observations/athenry/today
# ~~~
#
# <br>
# <br>
#
# <span style="color:red">**Note**:</span> Running the command `man curl` in the command line opens up the manual for the `curl` command to get more information on options available that can be used on it.

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">**Task 7: Write the Script**</span>
# >*Write a bash script called `weather.sh` in the root of your repository. This script should automate the process from Task 6, saving the weather data to the `data/weather` directory. Make the script executable and test it by running it.*
# ***

# %% [markdown]
# Before getting into the write up of this task, I firstly wanted to carry out some research into what a **Bash Shell** and a **Bash Script** are in **Linux** to get myself more familiar with the environment used. From my research, my understanding of these concepts are outlined below.
#
# ### <ins><span style="color:blue">What is a **Bash Shell** in Linux?</ins></span>
#
# To get more of an understanding of what a `shell` is in Linux, I sourced some information from [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/introduction-linux-shell-shell-scripting/)<sup>49</sup>, [datacamp (2022)](https://www.datacamp.com/blog/what-is-shell)<sup>50</sup> and [Fisher. T. (2024)](https://www.lifewire.com/guide-to-command-line-interpreters-8734407)<sup>51</sup>. From these sources, I understand that a non graphical `shell` is a program which interprets the commands that the user inputs on the command line interface (terminal) and these are directed to the operating system of the computer. The operating system then processes these commands [Wikipedia (2024)](https://en.wikipedia.org/wiki/Operating_system)<sup>52</sup>. A `Bash (Bourne Again Shell)` then is a type of `shell` program [Klein. M. (2024)](https://www.codecademy.com/resources/blog/what-is-bash-used-for/)<sup>53</sup>. According to [phoenixNAP Global Services (2024)](https://phoenixnap.com/kb/linux-shells)<sup>54</sup>, there are 8 different types of `Linux Shells`. Of these 8 `Linux Shells`, **Bash** is one of the most common amongst Linux users [software carpentry (2023)](https://swcarpentry.github.io/shell-novice/01-intro.html)<sup>55</sup>, [Kili, A. (2023)](https://www.tecmint.com/different-types-of-linux-shells/)<sup>56</sup> and [wikipedia (2024)](https://en.wikipedia.org/wiki/Bash_(Unix_shell))<sup>57</sup>.
#
#
# ### <ins><span style="color:blue">What is a **Bash Script** in Linux?</ins></span>
# A `Bash Script` is a text file containing a command or series of commands. Any commands that can be run directly on the command line interface can be put into a `script` and it will produce the same result as if it was run manually by the user on the command line [datacamp (2022)](https://www.datacamp.com/tutorial/how-to-write-bash-script-tutorial)<sup>58</sup>. Repetitive tasks can be put into a `script` and can be automated so that the user does not need to carry out long tedious tasks manually - instead the pre-written `script` is run. Scripting is very useful for automating routine tasks [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/bash-scripting-introduction-to-bash-and-bash-scripting/?ref=header_outind#applications-of-bash-scripts) <sup>59</sup>.
#
# The first line of a **Bash Script** always contains a `shebang` which is a combination of `bash #` and `bang !`. This creates an absolute path to the **bash interpreter** [Hira. Z(2022)](https://www.freecodecamp.org/news/shell-scripting-crash-course-how-to-write-bash-scripts-in-linux/#:~:text=Shell%20scripting%20is%20an%20important,certain%20commands%20again%20and%20again.)<sup>60</sup> and consequently tells the operating system which shell interpreter to use [tutorialspoint (2024)](https://www.tutorialspoint.com/using-shebang-hash-in-linux-scripts#:~:text=On%20Linux%2C%20a%20shebang%20(%23,the%20path%20to%20the%20interpreter.))<sup>61</sup> (which will be **Bash** for this task).

# %% [markdown]
# ### <ins><span style="color:blue">Creating the `weather.sh` script</ins></span>
# The first step of this task is to create a `weather.sh` script in the **root** of my repository. To do this, I have used the `nano` Text Editor [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/nano-text-editor-in-linux/)<sup>62</sup>. In the command line interface I have used the following command to create the new file:
#
# <br>
#
# ~~~bash
# nano weather.sh
# ~~~
# <br>
# <br>
#
# The above command creates the new script and also opens up the `nano` text editor on the command line which allows me to add my text command to it. Below, shows the full `wget` command (which I have already created in *Tasks 5 & 6*) which I inputted into the `weather.sh` script. The first line of the script contains the *shebang* (`#! /bin/bash`) which is explained above under the **What is a Bash Script in Linux?** heading. This tells the computer what shell is to be used to run or execute the script. In the case of this task it is the `bash` shell that is used:
#
# <br>
#
# ~~~bash
# #! /bin/bash
# wget -O `date +"%Y%m%d_%H%M%S_athenry.json"` https://prodapi.metweb.ie/observations/athenry/today
# ~~~
# <br>
# <br>
#
# To save my script in `nano`, on my keyboard, I firstly press `ctrl` + `o` and then press the `enter` key to save the file with the `weather.sh`. To exit out of the `nano` text editor then, I press `ctrl` + `x`. The `nano` editor then closes and brings the me back to the normal command line interface again.
#
# ### <ins><span style = "color:blue">Making the `weather.sh` script executable</ins></span>
# At this point, I have now created my `weather.sh` script that will automate the downloading of the data using an API. However, the script is not yet in executable format which in other words means that it is a program that cannot be run. In Codespaces, if the `ls -al` command is run in the **root** of my repository (/workspaces/computer_infrastructure_2024), the following output is presented in the terminal:
#
#
# <img src="img/not_executable.png" alt="output ls-al command showing script not executable" width="1000">
#
# The above image shows all of the directories and files in the **root** directory. Focusing on the last file `weather.sh`, the permissions are `-rw-rw-rw-` which means that users can read and write to the file but they cannot execute it. To change the user permissions and make the `weather.sh` file executable, in the **root** directory I have used the [chmod](https://www.geeksforgeeks.org/chmod-command-linux/)<sup>63</sup> command:
#
# <br>
#
# ~~~bash
# chmod u+x ./weather.sh
# ~~~
#
# <br>
# <br>
#
# Running the `ls -al` command again in the terminal now gives the following permissions details for the script:
#
# <img src="img/executable.png" alt="output ls-al command showing script executable" width="1000">
#
# Above we can see that the color of the `weather.sh` has changed to green and the permissions on the file are now `-rwxrw-rw-` which means only the owner of the file can run or execute the script.
#
# If `chmod +x ./weather.sh` command is used instead of `chmod u+x ./weather.sh`, then the script would be executable for all users [Brown. K (2023)](https://linuxconfig.org/understanding-chmod-the-difference-between-ux-and-x)<sup>64</sup> and not just the owner of the file.
#
#
# ### <ins><span style = "color:blue">Directing the output of the `weather.sh` script to the `data/weather` directory</ins></span>
#
# The script is now executable but when run it is going to create a new file containing the data in the **root** of my repository as this is where my `weather.sh` script is located. In order to redirect the output of the script to the `data/weather/` directory, I have added the path to the `data/weather/` directory between the `wget` command and the `date` command:
#
# <br>
#
# ~~~bash
# #! /bin/bash
# wget -O /data/weather`date +"%Y%m%d_%H%M%S_athenry.json"` https://prodapi.metweb.ie/observations/athenry/today
# ~~~
# <br>
# <br>
#
# Both the `weather.sh` script and the `data` directories are both in the **root** of my repository and the `weather` directory is a subdirectory of the `data` directory, so by adding the path to the `data/weather/` directory means the output of the script is redirected to `data/weather/`.

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">**Task 9: pandas**</span>
# >*In your `weather.ipynb` notebook, use the `pandas` function `read_json()` to load in any one of the weather data files you have downloaded with your script. Examine and summarize the data. Use the information provided data.gov.ie to write a short explanation of what the data set contains.*
# ***

# %% [markdown]
# ### <ins><span style="color:blue">Introduction</ins></span>
# Pandas is a built in Python Library which is used to read in data files/datasets into a DataFrame format and allows the user to clean, analyse, explore and manipulate the data. (https://www.w3schools.com/python/pandas/pandas_intro.asp)<sup>65</sup>. A Library is a collection of pre-written code or modules of code that are used so that programmers do not need to write out the code themselves for different programmes [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/libraries-in-python/)<sup>66</sup>.

# %% [markdown]
# #### <ins><span style="color:blue">A Brief explanation of the contents of the data set<ins></span>
#
#  Before going ahead and reading in the data set, firstly using [data.gov.ie](https://data.gov.ie/dataset/todays-weather-athenry)<sup>67</sup>, I have given a brief description of what it contains. The data set contains a list of observations which is updated on the hour, every hour for the current day for one area that is Athenry in County Galway. The values of the *time* variable are in [local time]( https://en.wikipedia.org/wiki/Local_time#:~:text=Local%20time%20is%20the%20time,time%20where%20and%20when%20applicable.)<sup>68</sup>. The variables in the data set are as follows:
#
# **1. Name:** The name of the area where the observations have been recorded
#
# **2. Dry bulb temperature in whole degrees:** The temperature measured by a thermometer which is exposed to the air but is shielded from radiation and is usually described as air temperature [Wikipedia, 2024]( https://en.wikipedia.org/wiki/Dry-bulb_temperature)<sup>69</sup>.
#
# **3. Weather description:** A one or two worded general description of the weather. Eg. Fair, cloudy etc.
#
# **4. Windspeed (kt):** The wind speed measured in the unit of speed called *knots*. 1 knot is equal to 1.852 kilometers per hour [Wikipedia]( https://en.wikipedia.org/wiki/Knot_(unit))<sup>70</sup>.
#
# **5. Cardinal Wind Direction:** The direction in which the wind is coming from (or where it originated). The data set also contains a variable called *Wind Direction* which is reported in compass direction or in degrees, where a wind blowing from the north is referred to as 0&deg; (360&deg;), a wind blowing from the east is referred to as 90&deg; and so on [Wikipedia (2024)]( https://en.wikipedia.org/wiki/Wind_direction)<sup>71</sup>.
#
# **6. Relative Humidity (%):** This variable is expressed as a percentage (%). It indicates the present state of absolute humidity - which is a mass of water vapor per volume of moist air or dry air -   relative to a maximum humidity given the same temperature [Wikipedia (2024]( https://en.wikipedia.org/wiki/Humidity)<sup>72</sup>.
#
# **7. Rainfall (mm):** The measurement of rainfall in mm in the hour leading up to the hour the observations were recorded.
#
# **8. msl Pressure (mbar):*** The atmospheric pressure at mean sea level and measured in millibars (mbar) [Wikipedia (2024)](https://en.wikipedia.org/wiki/Atmospheric_pressure)<sup>73</sup>.
#
# **9.Day of the week:** The day of the week that is under observation.
#
# **10. Date:** The date for which the observations were recorded.
#
# **11. Time of observation:** The time the observations were recorded.
#
# **The data set also contains 2 more variables which are not noted on [data.gov.ie ](https://data.gov.ie/dataset/todays-weather-athenry):**<sup>74</sup>
#
# **- Symbol:** These are symbols or images used to express the weather in visual form However as it is not possible to show anything graphical on the command line interface, codes are used in place of the graphical images. I was unable to source these from the Met Éireann website but sourced examples of some of these codes from a UK weather website [Open Weather]( https://openweathermap.org/weather-conditions)<sup>75</sup>.
#
# **- Text:** As far as I can understand this is just more description on the *weatherDescription* variable.
#
# This data set is not a forecast of weather but rather a description of the weather that has been recorded throughout the day.
#  For the purpose of this task, the data set is downloaded in the format or in JSON format via API but could also be download in [CSV (2024]( https://en.wikipedia.org/wiki/Comma-separated_values)<sup>76</sup> format.

# %% [markdown]
# #### <ins><span style="color:blue">Reading in the timestamped `.json` file</ins></span>
#
# At the top of this notebook, I have already imported the [pandas](https://pandas.pydata.org/docs/)<sup>77</sup> Library which means the pre-written functions of it are made available to me in the Python Environment.
#
# Using code adapted from [pandas DataFrames](https://neuraldatascience.io/3-python/pandas_dataframes.html) documentation<sup>78</sup>, below, I have read in the `20241128_204806_athenry.json` file which is the weather dataset for Athenry for Thursday the 28/11/2024 which is located in the `data/weather` directory. I have given the path to the `data/weather` directory so that `pandas` can locate the `.json` file. I have stored the read in file as a variable called `df` so for simplicity going forward, I can reference the read in file as `df`.

# %%
# Read in the .json file from the data/weather directory using pandas and store as variable 'df'
df = pd.read_json('data/weather/20241128_204806_athenry.json')

# %%
# Show the DataFrame 
print("\t\t\t\t Weather Data for Athenry on 28/11/2024 \n")
df
# Out:
# 				 Weather Data for Athenry on 28/11/2024
#        name  temperature symbol weatherDescription                 text  \
# 0   Athenry           -2    15n         Fog / Mist               "Mist"
# 1   Athenry           -2    02n               Fair               "Fair"
# 2   Athenry           -2    02n               Fair               "Fair"
# 3   Athenry           -1    04n             Cloudy             "Cloudy"
# 4   Athenry            0    04n             Cloudy             "Cloudy"
# 5   Athenry            0    04n             Cloudy             "Cloudy"
# 6   Athenry            1    04n             Cloudy             "Cloudy"
# 7   Athenry            3    04n             Cloudy             "Cloudy"
# 8   Athenry            4    04d             Cloudy             "Cloudy"
# 9   Athenry            6    46d        Light rain         "Light rain "
# 10  Athenry            7    46d        Light rain         "Light rain "
# ...

# %% [markdown]
# ### <ins><span style="color:blue">Review of the DataFrame</ins></span>
#
#  As the above DataFrame is quite small, it is easy to establish how many rows and columns of data there is just by scrolling through it. However, if it were a larger DataFrame, [the df.shape](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html)<sup>79</sup> property of `pandas` can be used to establish its dimensions. Below, the `df.shape` property confirms that the DataFrame contains 21 rows and 15 columns of data.

# %%
df.shape
# Out:
# (21, 15)

# %% [markdown]
# #### <span style="color:blue">The DataFrames rows and columns</span>
# The DataFrame's rows are indexed from 0 through to 20. Indexes are labels that identify each row. According to the [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.index.html#pandas.DataFrame.index)<sup>80</sup> indexes can be of type integer (whole number) or strings. However, according to [Programiz](https://www.programiz.com/python-programming/pandas/index)<sup>81</sup>, if the index type is not specified by the user, `pandas` will by default assign integer indexes starting at 0 on the rows of data. As the columns have variable names of type string, these names are used to index the columns.

# %% [markdown]
# #### <span style="color:blue">The data types in the DataFrame</span>
#
# Using the [pandas df.dtypes](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html)<sup>82</sup> property below, the data type of each of the DataFrames' variables can be shown.

# %%
# Show the data types of each of the columns of the DataFrame
df.dtypes
# Out:
# name                             object
# temperature                       int64
# symbol                           object
# weatherDescription               object
# text                             object
# windSpeed                         int64
# windGust                         object
# cardinalWindDirection            object
# windDirection                     int64
# humidity                          int64
# rainfall                        float64
# pressure                          int64
# dayName                          object
# date                     datetime64[ns]
# reportTime                       object
# dtype: object

# %% [markdown]
# Firstly, looking at the variables *name*, *symbol*, *weatherDescription*, *text*, *windGust*, *cardinalWindDirection*, *dayName* and *reportTime* - all of these variables are shown by the `df.dtypes` property as type **object**. According to the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html)<sup>83</sup>, columns which contain mixed data types are stored as data type **object**. With regards to the *windGust* variable, my understanding as to why this is of type **object** is because it contains *missing values*. Missing values are of data type **float** [SSP (2023)](https://medium.com/@_SSP/types-of-null-values-e9e1fa7436e)<sup>84</sup>, so the column of data contains two different types of data and this is why it is of type **object**.
#
# Regarding the variables with text values, data of type **string** can vary in length so they are stored as **objects** by default [Siraj. S (2017)](https://stackoverflow.com/questions/33957720/how-to-convert-column-with-dtype-as-object-to-string-in-pandas-dataframe)<sup>85</sup>, [HYRY (2014)](https://stackoverflow.com/questions/21018654/strings-in-a-dataframe-but-dtype-is-object)<sup>86</sup>.
#
# The variables *temperature*, *windSpeed*, *windDirection*, *humidity* & *pressure* are stored as variables **int64** and lastly, *rainfall* is of type **float64**. **int64** data is numeric data and **float64** data is numeric characters with decimals [librarycarpentry (2016)](https://librarycarpentry.github.io/library-python/03-data-types-and-format/#:~:text=A%20type%20'O'%20just%20stands,is%20a%20string%20(characters))<sup>87</sup>.

# %% [markdown]
# #### <span style="color:blue">Describe the data</span>
#
# Below, [df.describe() method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)<sup>88</sup>, gives the total count of rows of data along with the the mean, standard deviation, minimum values, maximum values and 25th, 50th and 75th percentile values for all of the numeric variables which have no missing values.

# %%
df.describe()
# Out:
#        temperature  windSpeed  windDirection   humidity   rainfall  \
# count    21.000000  21.000000      21.000000  21.000000  21.000000
# mean      5.619048  17.190476     122.142857  90.476190   0.096190
# min      -2.000000  11.000000      90.000000  85.000000   0.000000
# 25%       0.000000  17.000000      90.000000  89.000000   0.000000
# 50%       7.000000  17.000000     135.000000  91.000000   0.000000
# 75%      10.000000  19.000000     135.000000  92.000000   0.010000
# max      14.000000  26.000000     180.000000  95.000000   0.900000
# std       5.370998   3.108360      28.964264   2.581067   0.230857
#
#           pressure                 date
# count    21.000000                   21
# mean   1017.857143  2024-11-28 00:00:00
# min    1014.000000  2024-11-28 00:00:00
# 25%    1015.000000  2024-11-28 00:00:00
# 50%    1018.000000  2024-11-28 00:00:00
# 75%    1020.000000  2024-11-28 00:00:00
# max    1022.000000  2024-11-28 00:00:00
# ...

# %% [markdown]
# #### <span style="color:blue">Visualising the data using Histplots</span>
#
# Below, adapting code from [seaborn.histplot](https://seaborn.pydata.org/generated/seaborn.histplot.html)<sup>89</sup>, [Matplotlib Subplot](https://www.w3schools.com/python/matplotlib_subplot.asp)<sup>90</sup> and [geeksforgeeks](https://www.geeksforgeeks.org/seaborn-style-and-color/)<sup>91</sup> and [kaggle](https://www.kaggle.com/code/abhishekmamidi/everything-you-can-do-with-seaborn)<sup>92</sup>, I have created histograms to get a visual representation of the occurrences of each of the numeric variables which have no missing values.

# %%
plt.figure(figsize=(20,20))
sns.set_style("darkgrid")


# Add data to the subplots
plt.subplot(3,2,1)
plt.title( "Plot 1. Temperature" , size = 15, color ="blue") 
sns.histplot(data=df, x ="temperature", bins =5, color = "lightgreen", edgecolor ="blue")

plt.subplot(3,2,2)
plt.title( "Plot 2. Wind Speed" , size = 15, color ="blue") 
sns.histplot(data=df, x ="windSpeed", bins =5, color = "lightgreen", edgecolor ="blue")

plt.subplot(3,2,3)
plt.title( "Plot 3. Wind Direction" , size = 15, color ="blue") 
sns.histplot(data=df, x ="windDirection", bins =5, color = "lightgreen", edgecolor ="blue")

plt.subplot(3,2,4)
plt.title( "Plot 3. Humidity" , size = 15, color ="blue") 
sns.histplot(data=df, x ="humidity", bins =5, color = "lightgreen", edgecolor ="blue")

plt.subplot(3,2,5)
plt.title( "Plot 3. Rainfall" , size = 15, color ="blue") 
sns.histplot(data=df, x ="rainfall", bins =5, color = "lightgreen", edgecolor ="blue")

plt.subplot(3,2,6)
plt.title( "Plot 3. Pressure" , size = 15, color ="blue") 
sns.histplot(data=df, x ="pressure", bins =5, color = "lightgreen", edgecolor ="blue")


# Show the subplots
plt.show()

# %% [markdown]
# From the plots above, I have established the following from the data set:
#
# **Plot 1:** Out of the 21 observations recorded, the temperature was at it's lowest (between -2&deg;  and 1&deg;) for the majority of them at (7 observations) and the temperature was at its highest, (between 11&deg;  and 14&deg;) for 4 of the 21 observations.
#
# **Plot 2:** The highest wind speed recorded of between 17kt and 20kt was the most frequent wind speed at about 15 observations.
#
# **Plot 3:**  The wind direction for the majority of the observations was a south-easterly wind (roughly 125&deg; to 145&deg;) followed by 8 observations showing a north-easterly and easterly wind (30&deg; to 110&deg;)
#
# **Plot 4:** Relative Humidity was at it's highest (between 91% & 93%) for the majority of the observations.
#
# **Plot 5:** Rainfall was at it's lowest (between 0mm and 0.18mm for the majority of the observations) and at it's highest (between about 0.75mm and 0.87) for just one of the observations.
#
# **Plot6:** Pressure is quite interesting as 6 of the observations showed the pressure at its lowest (between 1014 millibars and 1017millibars). However, 5 of the observations showed the pressure to be at it's highest (between 1020.5 millibars and 1022millibars).

# %% [markdown]
# #### <span style="color:blue">Visualising the data using Pairplots</span>
#
# Using the [seaborn.pairplot()](https://seaborn.pydata.org/generated/seaborn.pairplot.html)<sup>93</sup> function on the DataFrame, below I have generated a pairplot of all of the numerical data. At the top of this notebook, I have already imported the required library `seaborn` as `sns` for generating pairplots.
#
# Inputting `df` and `"hue = weatherDescription`as parameters, the function gives a visual representation of the data where each of the numerical variables are plotted against each other. Each dot on the plots represents a row from the DataFrame and the `hue = "weatherDescription"` adds a categorical variable from the DataFrame to the pairplot.
#
# According to the explanation given of positive and negative correlation by [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/scatter-diagram-correlation-meaning-interpretation-example/)<sup>94</sup>, on the plots below, the only two variables that would appear to have a strong correlation are **temperature** and **pressure** and they would appear to be negatively correlated as the data is aligned from the top left to the bottom right of the plot. This would mean that as **temperature** increased, **pressure** dropped.

# %%
# Creating pairplot
sns.pairplot(df, hue ="weatherDescription")

# Show pairplot 
plt.show()

# %% [markdown]
# #### <span style="color:blue">Checking for correlation between variables</span>
# Below, I have used [df.corr()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html)<sup>95</sup> which calculates the relationships between the numerical variables of the DataFrame. From [Smith. A (2024)](https://www.pickl.ai/blog/exploring-what-is-pandas-dataframe-corr-method-types-and-working/)<sup>96</sup>, I got more of an understanding as to what the results mean.
#
# The closer the result is to either **1** or **-1**, the stronger the correlation. If the result is close to **1**, the variables are positively correlated and if the result is close to **-1**, they are negatively correlated.
#
# From the `df.corr()` function, it is clear that **temperature** and **pressure** do in fact have a very strong negative relationship with a result of -0.976250. **Humidity** and **temperature** would also be considered to have a strong negative relationship with a result of -0.707610.

# %%
# Show the correlation between the numerical variables only 

df.corr(numeric_only=True)
# Out:
#                temperature  windSpeed  windDirection  humidity  rainfall  \
# temperature       1.000000   0.334004       0.907051 -0.707610  0.181846
# windSpeed         0.334004   1.000000       0.403431 -0.410730  0.093037
# windDirection     0.907051   0.403431       1.000000 -0.606236  0.194205
# humidity         -0.707610  -0.410730      -0.606236  1.000000 -0.078199
# rainfall          0.181846   0.093037       0.194205 -0.078199  1.000000
# pressure         -0.976250  -0.274929      -0.845973  0.679771 -0.109415
#
#                pressure
# temperature   -0.976250
# windSpeed     -0.274929
# windDirection -0.845973
# humidity       0.679771
# rainfall      -0.109415
# pressure       1.000000

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">**Project**</span>
# ***

# %% [markdown]
# ## <ins><span style="color:blue">Introduction</ins></span>
# The goal of this project is to automate my `weather.sh` script that I created in *Task 7* above so that this script runs daily, and the new data obtained by this script is pushed to my [computer_infrasctucture_2024]( https://github.com/OCorry/computer_infrastructure_2024/tree/main) repository using [GitHub Actions]( https://docs.github.com/en/actions/about-github-actions/understanding-github-actions).
#
# According to [Github Docs (2024)]( https://docs.github.com/en/actions/writing-workflows/about-workflows)<sup>97</sup>, a GitHub Actions workflow is a configurable automated process that will run one or more jobs and is defined by a YAML text file [GitHub Docs, 2024]( https://docs.github.com/en/actions/writing-workflows/workflow-syntax-for-github-actions#about-yaml-syntax-for-workflows)<sup>98</sup>. YAML is a text configuration file that contains the instructions for the workflow to carry out the action (automating the running of the `weather.sh` script). For this reason, the YAML file must be saved in the `.github/workflows` directory of the repository.
#
# The repository must contain one or more [events]( https://docs.github.com/en/actions/about-github-actions/understanding-github-actions)<sup>99</sup> which will trigger the workflow, and a repository can have multiple workflows. For this project, there will be just one event which is running the `weather.sh` script daily at 10am and one workflow containing a job which is to automate this process.

# %% [markdown]
# ### <ins><span style="color:blue">Creating my GitHub Actions Workflow</span></ins>
# Firstly, in the **root** of my repository, using the [mkdir -p]( https://phoenixnap.com/kb/create-directory-linux-mkdir-command)<sup>100</sup> command, I have created a directory called `.github` and within that another subdirectory called `workflows`:
#
# <br>
#
# ~~~bash
# mkdir -p .github/workflows/
# ~~~
# <br>
# <br>

# %% [markdown]
# Next,  using the [cd]( https://www.geeksforgeeks.org/cd-command-in-linux-with-examples/)<sup>101</sup> command I navigate into the `.github/workflows/` directory, and using the [touch]( https://www.geeksforgeeks.org/touch-command-in-linux-with-examples/)<sup>102</sup> command, I have created a [YAML]( https://en.wikipedia.org/wiki/YAML#:~:text=Its%20initial%20name%20was%20intended,oriented%2C%20rather%20than%20document%20markup)<sup>103</sup> file called `weather-data.yml`.
#
# <br>
#
# ~~~bash
# touch weather-data.yml
# ~~~

# %% [markdown]
# ### <ins><span style="color:blue">Contents of my YAML file</span></ins>
# I have sourced code from [ChatGPT](https://chatgpt.com/)<sup>104</sup> to create my  `weather-data.yml` file. I specified the following when asking ChatGPT for the code:
#
# **1.** I have a GitHub repository which contains a bash script called `weather.sh` and a    requirements.txt file. The requirements.txt file contains and pip requirements to run my weather.sh script.
# </br>
# **2.** Write a GitHub Actions YAML file that firstly clones my repository to GitHub Actions.
# </br>
# **3.** Next, make sure that the most up to date version of Python is installed.
# </br>
# **4.** Then, install the requirements in requirements.txt.
# </br>
# **5.** Next, make sure my weather.sh script is executable.
# </br>
# **6.** After that, make my weather.sh script run at 10am every day
# </br>
# **7.** Finally push the changes back to my repository and make sure the required permissions are included to push changes back to my repository.
#
# With the above information, ChatGPT gave me code to populate my [weather-data.yml text file](./weather-data.yml). The file consists of a number of  key-value pairs and are separated by a colon `:`, where the key is the unique identifier of the pair, and the value is the details of the pair.

# %% [markdown]
# ### <ins><span style="color:blue">Explanation of my `weather-data.yml` file</span></ins>
# **<span style="color:blue">1.</span>** At the top of the file, the first key-value pair is the `name` of my workflow which is **Run Weather Script and Push Changes to Repository**. This is the name that will appear in the **Actions** tab in my repository when I go ahead and run my GitHub Actions workflow. It appears in my YAML file as follows:
#
# <br>
#
# ~~~YAML
# name: Run Weather Script and Push Changes to Repository
# ~~~
# <br>
# <br>
#
# **<span style="color:blue">2.</span>** Next, is the `on` key which is the event that is going to happen that triggers the workflow to run. In this case, the event is `schedule` which will create a scheduled event using a job scheduler called [cron]( https://en.wikipedia.org/wiki/Cron)<sup>105</sup>. This scheduled event is to happen every morning at 10am. The `cron` syntax is as follows: `0 10 * * *` where 0 denotes the minutes, 10 denotes the hours, and the last three asterisks (`*`) denote, the day of the month, the month and the day of the week respectively. The `0`in the minutes section means that `cron` is <ins>not</ins>  set to run on the minute. The three asterisks  (`*`) mean that `cron` will make the event run on every day of every month, on every month of the year, and on every day of the week respectively [Cronitor, (2024)]( https://crontab.guru/#0_10_*_*_*)<sup>106</sup>.
#
# I have also included [workflow dispatch]( https://docs.github.com/en/actions/managing-workflow-runs-and-deployments/managing-workflow-runs/manually-running-a-workflow)<sup>107</sup> which means that I can manually trigger the workflow to make sure it runs successfully rather than having to wait for the scheduled event to trigger it.
#
# <br>
#
# ~~~YAML
# on:
#   schedule:
#     - cron: '0 10 * * *' # Runs the weather.sh script every day at 10:00 AM UTC
#   workflow_dispatch: # Allows me to trigger the script to start manually
# ~~~
# <br>
# <br>
#
# **<span style="color:blue">3.</span>** The next part is the `permissions` key. This needs to be included in the file to allow permissions to push the changes made by the `weather.sh` script back up to my repository. The contents of the permissions are `write` which allows the user to push changes back to the repository:
#
# <br>
#
# ~~~YAML
# permissions:
#   contents: write
# ~~~
# <br>
# <br>
#
# <span style="color:red">**Note:**</span> This setting can also be changed manually in my GitHub repository settings if I go to my repository and click `Settings` > `Actions` > `General` and scroll down to `Workflow permissions` section  and tick  the `Read and write permissions` [GitHub Action for GitHub Push]( https://github.com/marketplace/actions/github-push)<sup>108</sup>.
#
#
# **<span style="color:blue">4.</span>** Next is the `jobs` key which contains the job I have asked the workflow to do. The job is to run the `weather.sh` script. It is specified that the script is to be run on a Ubuntu virtual machine. Ubuntu is one of GitHub’s **hosted runners** and if a Ubuntu **runner** is specified, each time a workflow executes, it is executed in a new Ubuntu virtual machine [GitHub Docs, (2024)]( https://docs.github.com/en/actions/using-github-hosted-runners/using-github-hosted-runners/about-github-hosted-runners)<sup>109</sup> & [GitHub Docs, (2024)]( https://docs.github.com/en/actions/about-github-actions/understanding-github-actions)<sup>110</sup>.
#
# <br>
#
# ~~~YAML
# jobs:
#   run-weather-script:
#     runs-on: ubuntu-latest
# ~~~

# %% [markdown]
# Within the `jobs` section of the file, there are a number of steps:
#
# #### <span style="color:blue">Step 1 - Check out the repository:</span>
#
# This means that my repository on which I want to carry out the action is located and cloned to GitHub Actions. To do this, an action called `actions/checkout` is used. This is a pre-made Actions script already available to use [GitHub checkout, (2024)](https://github.com/actions/checkout)<sup>111</sup> . This clones my repository to the GitHub Actions  environment.
# To get more of an understanding of this process, I sourced information from [Foster. G (2024)]( https://graphite.dev/guides/github-actions-checkout)<sup>112</sup>. Below we can see that `actions/checkout@v3` is used to check out and clone my repository to GitHub Actions:
#
# <br>
#
# ~~~YAML
#   steps:
#   - name: Check out the repository
#     uses: actions/checkout@v3
# ~~~
# <br>
# <br>
#
# This step is required because GitHub Actions does not automatically clone the repository into the GitHub Actions Virtual Machine being used (unlike Codespaces).
#
#
# #### <span style="color:blue">Step 2 - Make sure `weather.sh` is executable using `chmod +x weather.sh` and run it:</span>
#
#  In *Task 7* above, I made my `weather.sh` script executable in my Codepsaces environment. However, as I am now using the GitHub Actions Workflow (using Ubuntu Environment), the process of making the script executable needs to be carried out again as I am using a different environment. This is done as follows:
#
# <br>
#
# ~~~YAML
#   - name: Make weather.sh executable and run it
#     run: |
#       chmod +x weather.sh
#       ./weather.sh
# ~~~
# <br>
# <br>
#
# The pipe `|` character is used above as there are multiple lines of code to be run on this step. It ensure that the format of lines of the command are correct and that all lines of code run correctly [Bevans Bench](https://www.bevansbench.com/blog/understanding-pipe-character-yaml-multiline-strings-explained)<sup>113</sup>.
#
# The first line of the command uses the `chmod +x` command to allow the user permissions to execute the file. [GeeksforGeeks (2024)](https://www.geeksforgeeks.org/what-does-chmod-x-do-and-how-to-use-it/)<sup>114</sup>.
#
# The second line of the command, `./weather.sh` is the command to run the script. The `./` ahead of the script name is required here as Linux does not recognise the current working directory as being in the [PATH](https://phoenixnap.com/kb/linux-add-to-path#:~:text=PATH%20is%20an%20environment%20variable,to%20remove%20it%20in%20Linux.)<sup>115</sup>, so the PATH needs to be specified [Elofsson. J & Floris (2023)](https://superuser.com/questions/586636/why-do-i-need-a-before-executing-some-scripts)<sup>116</sup>.
#
# #### <span style="color:blue">Step 3 - Configure git for committing and pushing changes up to the repository:</span>
#
#  Git is already installed in the Ubuntu environment by default but it needs to be configured to identify the user for committing and pushing changes back up to the GitHub repository. Git is configured using a `user.name` and `user.email` [GitHub Documentation](https://docs.github.com/en/get-started/getting-started-with-git/set-up-git)<sup>117</sup>:
#
# <br>
#
# ~~~YAML
#   - name: Configure git
#   run: |
#     git config user.name "github-actions[bot]"
#     git config user.email "github-actions[bot]@users.noreply.github.com"
# ~~~
# <br>
# <br>
#
# #### <span style="color:blue">Step 4 - Commit changes and push changes to my repository:</span>
#
# This step contains what is required to successfully push changes back up to the GitHub repository:
#
# <br>
#
# ~~~YAML
#   - name: Commit and push changes
#   run: |
#     git add .
#     git commit -m "Automated update by GitHub Actions"
#     git push
#   env:
#     GITHUB_TOKEN: ${{ secrets.GITHUB_TOKEN }}
# ~~~
# <br>
# <br>
#
# Here, just like using a command line interface to push changes to a repository, firstly `git add .` is run add any changes to the staging area, then `git commit -m "<comment>"` commits the changes with a brief comment explaining the changes made and lastly `git push` pushes the changes up to the repository [Git Guides(2024)](https://github.com/git-guides)<sup>118</sup>. The `GITHUB_TOKEN`authenticates the workflow and expires when the workflow is complete [GitHub Docs (2024)](https://docs.github.com/en/actions/security-for-github-actions/security-guides/automatic-token-authentication)<sup>119</sup>.
#
# #### <span style="color:blue">Step 5 - Notify Codespace users</span>
#
# The final step in the **jobs** section of the YAML file gives the user a reminder at the end of the Actions Workflow log that they need to pull the changes to their Codespaces.
#
# <br>
#
# ~~~YAML
#   - name: Notify Codespaces Users
#     run: |
#       echo "Changes have been pushed to the repository. To sync, run the following commands in Codespaces:"
#       echo "git pull"
# ~~~
# <br>
# <br>
#
# When ChatGPT generated the code for my YAML file, it also included the following two steps in the **jobs** section of the file:
#
# <br>
#
# ~~~YAML
#   - name: Set up Python
#         uses: actions/setup-python@v4
#         with:
#           python-version: 3.x
# ~~~
#
# ~~~YAML
#   - name: Install Python dependencies
#         run: |
#           python -m pip install --upgrade pip
#           pip install -r requirements.txt
# ~~~
# <br>
# <br>
#
# However, I have removed these from my YAML script as I do not need Python or any Python packages for the successful running of my script as it is a `Bash` script and not a `Python` script.

# %% [markdown]
# ### <ins><span style="color:blue">Running my GitHub Actions Workflow</span></ins>
# With my YAML file and my Bash script completed, my GitHub Actions workflow runs at 10am daily and downloads that day's weather data for Athenry that is available from 00:00hrs up until the time it runs.
#
# I can test that my workflow works as I have included the `workflow_dispatch` in my YAML file. To test it, I go to my repository [computer_infrastructure_2024](https://github.com/OCorry/computer_infrastructure_2024/tree/main) and click on the `Actions` tab at the top. Once in the `Actions` tab, on the left side of the screen, I click on `Run Weather Script and Push Changes to Repository` (which is the name at the very top of my YAML file). Then I click on `Run wrokflow` and this runs the workflow in the background. I do not have any access to this process but I can click on the workflow name and then on `run-weather-script` to see the log of the progress of the Workflow. A successful workflow log would look something like this:
#
# <img src="img/workflow_log.png" alt="Example of Successful workflow log" width="1000">
#
# I have noticed that while my workflows are running successfully, they do not run at exactly 10am each morning. This is evident from the timestamps on the automated updated files in my `data/weather/` directory.. According to [Kumar. S (2023)](https://www.sivamuthukumar.com/blog/ghactions-scheduled-workflows-external-trigger)<sup>120</sup>, this is not unusual as there are many other users and many other workflows competing for resources to run.

# %% [markdown]
# ## <span style="color:blue">End</span>
# ***

# %% [markdown]
# ## <span style="color:blue">References</span>
# ***
#
# ##### Task 1
# 1. GeeksforGeeks. Libraries in Python. 01 Aug, 2024 <br> https://www.geeksforgeeks.org/libraries-in-python/
# 2. Sandra Henry Stocker. Netwrok World. Creating and removing directory structures on Linux (2023) </br> https://www.networkworld.com/article/971782/creating-and-removing-directory-structures-on-linux.html#:~:text=Each%20group%20of%20directory%20names,being%20created%20at%20that%20level.&text=You%20can%20add%20as%20many,specifications%20to%20the%20mkdir%20command.
# 3. Wikipedia Hierarchical file system (2024) br> https://en.wikipedia.org/wiki/Hierarchical_file_system
# 4. Zaira Hira. How to Create Diagrams as Code with Mermaid, GitHub, and Visual Studio Code. (2023) <br> https://www.freecodecamp.org/news/diagrams-as-code-with-mermaid-github-and-vs-code/
# 5. jojozhuang. 9724. Mermaid Cheat Sheet (2021) <br> https://jojozhuang.github.io/tutorial/mermaid-cheat-sheet/
# 6. Visual Studio| Marketplace. Mermaid Comment (2024) <br> https://marketplace.visualstudio.com/items?itemName=CatBraaain.mermaid-comment#:~:text=Comment%20with%20%60%25%25%60%20for,lines%2C%20with%20a%20single%20command.&text=Launch%20VS%20Code%20Quick%20Open,following%20command%2C%20and%20press%20enter
# 7. Github.com. Brackets in a node with text? (2015) <br> https://github.com/mermaid-js/mermaid/issues/213
# 8. Wikipedia. Root Directory (2024). <br> https://en.wikipedia.org/wiki/Root_directory
# 9. Foster. G. Graphite. How to add an empty directory in git (2024) <br> https://graphite.dev/guides/add-empty-dir
# 10. GeeksforGeeks. How to Add an Empty Directory to a Git Repository? (2023) <br> https://www.geeksforgeeks.org/how-to-add-an-empty-directory-to-a-git-repository/
# 11. Parr. K. freeCodeCamp. What is .gitkeep? How to Track and Push Empty Folders in Git (2021) <br> https://www.freecodecamp.org/news/what-is-gitkeep/
# 12. GeeksforGeeks. How to Create an Empty File in Linux | Touch Command (2024) <br> https://www.geeksforgeeks.org/touch-command-in-linux-with-examples/
# 13. GeeksforGeeks. rm command in Linux with examples (2024) <br> https://www.geeksforgeeks.org/rm-command-linux-examples/
# <br>
#
# ##### Task 2
# 14. Wikipedia. Command-line interface (2024) <br> https://en.wikipedia.org/wiki/Command-line_interface
# 15. GeeksforGeeks. How to Display and Set Date and Time in Linux | date Command (2024) <br> https://www.geeksforgeeks.org/date-command-linux-examples/
# 16. Wikipedia. Coordinated Universal Time (2024) <br> https://en.wikipedia.org/wiki/Coordinated_Universal_Time
# 17. Damon Garn. Red Hat Blog. Five ways to use redirect operators in Bash (2021) <br> https://www.redhat.com/en/blog/redirect-operators-bash#:~:text=The%20append%20%3E%3E%20operator%20adds%20the,uname%20%2Dr%20to%20the%20specifications.
# 18. GeeksforGeeks more command in Linux with Examples (2024) <br> https://www.geeksforgeeks.org/more-command-in-linux-with-examples/
# <br>
#
# ##### Task 3
# 19. phoenixnap. Global IT Services. Linux Date Command: How to Set, Change, Format Date in Linux. (2024) <br> https://phoenixnap.com/kb/linux-date-command
# <br>
#
# ##### Task 4
# 20. GeeksforGeeks. How to Create an Empty File in Linux | Touch Command (2024) <br> https://www.geeksforgeeks.org/touch-command-in-linux-with-examples/
# 21. GeeksforGeeks. Shell Scripting – Command Substitution (2022) <br> https://www.geeksforgeeks.org/shell-scripting-command-substitution/
# 22. Linux Leech. Backticks Command Substitution in Linux (Youtube Video). (2014) <br> https://www.youtube.com/watch?v=VOOeXV4HYSA
# 23. Stackoverflow. Command substitution: backticks or dollar sign / paren enclosed? [duplicate]. (2014) <br> https://stackoverflow.com/questions/9405478/command-substitution-backticks-or-dollar-sign-paren-enclosed
# 24. Roberto Nozaki. Red Hat. Bash scripting: Moving from backtick operator to $ parentheses (2021) <br> https://www.redhat.com/en/blog/backtick-operator-vs-parens
# <br>
#
# ##### Task 5
# 25. https://prodapi.metweb.ie/observations/athenry/today
# 26. Codú. What Is an API? Explained in Plain English (Youtube video)<br> (https://www.youtube.com/watch?v=Td0nwrNzVv4)
# 27. Exponent. APIs Explained (in 4 Minutes). (Youtube video)<br>https://www.youtube.com/watch?v=bxuYDT-BWaI
# 28. atatus. A Beginner's Guide to API Data Formats: JSON, XML, Plain Text, and Binary (2023)<br>https://www.atatus.com/blog/guide-to-api-data-formats-json-xml-plain-text-and-binary/
# 29. Wikipedia. URL (2024) <br> https://en.wikipedia.org/wiki/URL
# 30. Cloudflare. What is HTTP? (2024)<br> https://www.cloudflare.com/learning/ddos/glossary/hypertext-transfer-protocol-http/
# 31. Cloudflare. What is a protocol? | Network protocol definition. (2024) <br> https://www.cloudflare.com/learning/network-layer/what-is-a-protocol/
# 32. Wikipedia. HTTP. (2024) <br> https://en.wikipedia.org/wiki/HTTPS#:~:text=This%20is%20the%20latest%20accepted,Hypertext%20Transfer%20Protocol%20(HTTP).
# 33. Trai.ai. How do APIs work? (2024)   https://tray.ai/blog/how-do-apis-work
# 34. w3schools. HTTP Status Messages. (2024). <br>  https://www.w3schools.com/tags/ref_httpmessages.asp
# 35. Postman. API authentication (2024)<br> https://www.postman.com/api-platform/api-authentication/#:~:text=There%20are%20many%20types%20of,the%20API%20is%20not%20misused.
# 36. frontegg. API Authentication and Authorization: 6 Methods and Tips for Success (2023) <br> https://frontegg.com/guides/api-authentication-api-authorization#:~:text=Data%20security%3A%20By%20requiring%20authentication,access%2C%20theft%2C%20or%20misuse.
# 37. mdn web docs_ HTTP response status codes (2024)<br>  https://developer.mozilla.org/en-US/docs/Web/HTTP/Status
# 38. GeeksforGeeks. How to Change the Directory in Linux | cd Command (2024)<br>  https://www.geeksforgeeks.org/cd-command-in-linux-with-examples/
# 39. GeeksforGeeks. Wget Command in Linux/Unix (2024)<br>  https://www.geeksforgeeks.org/wget-command-in-linux-unix/
# 40. w3schools. JSON syntax. (2024) <br> https://www.w3schools.com/js/js_json_syntax.asp
# 41. GeeksforGeeks. How to Format JSON in VSCode (2024)<br> https://www.geeksforgeeks.org/how-to-format-json-in-vscode/
# 42. w3schools.HTTP Status Messages (2024) <br> https://www.w3schools.com/tags/ref_httpmessages.asp
# <br>
#
# ##### Task 6
# 43. Mucuho. Carlos & Lee. Rachel.How To Use Wget to Download Files and Interact with REST APIs (2021) <br> https://www.digitalocean.com/community/tutorials/how-to-use-wget-to-download-files-and-interact-with-rest-apis
# 44. GeeksforGeeks. Wget Command in Linux/Unix (2024) <br> https://www.geeksforgeeks.org/wget-command-in-linux-unix/
# 45. joshtronic & Hogan.B. How to Download Files with cURL. (2021). <br> https://www.digitalocean.com/community/tutorials/workflow-downloading-files-curl
# 46. Ludosanu. Razvan. How to Download Files with curl And wget. (2024)<br> https://www.warp.dev/terminus/curl-vs-wget
# 47. oxylabs. Pelakauskas. How to Download Files with cURL. (2024)<br> https://oxylabs.io/blog/curl-download-file
# 48. joshtronic & Hogan.B. How to Download Files with cURL. (2021)<br> https://www.digitalocean.com/community/tutorials/workflow-downloading-files-curl
# <br>
#
# ##### Task 7
# 49. GeeksforGeeks Introduction of Linux Shell and Shell Scripting (2024) <br> https://www.geeksforgeeks.org/introduction-linux-shell-shell-scripting/
# 50. datacamp. What is a Shell? (2022) <br> https://www.datacamp.com/blog/what-is-shell
# 51. Fisher. Tim. Lifewire. Unlocking the Power of Command Line Interpreters: A Guide for Tech Enthusiasts (2024)<br> https://www.lifewire.com/guide-to-command-line-interpreters-8734407
# 52. Wikipedia. Operating System (2024). <br> https://en.wikipedia.org/wiki/Operating_system
# 53. Klein. M. codecademy. What is Bash Used for? (2024) <br> https://www.codecademy.com/resources/blog/what-is-bash-used-for/
# 54. phoenixNAP Global IT services. 8 Types of Linux Shells. (2022)<br> https://phoenixnap.com/kb/linux-shells
# 55. software carpentry. Introducing the Shell. (2023)<br>https://swcarpentry.github.io/shell-novice/01-intro.html
# 56. Kili. A. Tecmint Linux Blog. 5 Most Frequesntly used Open Source Shells for Linux. <br> https://www.tecmint.com/different-types-of-linux-shells/
# 57. Wikipedia. Bash (Unix shell). (2024). <br> https://en.wikipedia.org/wiki/Bash_(Unix_shell)
# 58. datacamp. How to Write a Bash Script: A Simple Bash Scripting Tutorial. (2022). <br> https://www.datacamp.com/tutorial/how-to-write-bash-script-tutorial
# 59. GeeksforGeeks. Bash Scripting - Introduction to Bash and Bash Scripting (2024). <br> https://www.geeksforgeeks.org/bash-scripting-introduction-to-bash-and-bash-scripting/?ref=header_outind#applications-of-bash-scripts
# 60. Hira. Z. freecodecamp Shell Scripting for Beginners - How to Write Bash Scripts in Linux (2022) <br> https://www.freecodecamp.org/news/shell-scripting-crash-course-how-to-write-bash-scripts-in-linux/#:~:text=Shell%20scripting%20is%20an%20important,certain%20commands%20again%20and%20again.
# 61. tutirialspoint. Using the Shebang #! in Linux Scripts. (2024). <br> https://www.tutorialspoint.com/using-shebang-hash-in-linux-scripts#:~:text=On%20Linux%2C%20a%20shebang%20(%23,the%20path%20to%20the%20interpreter.)
# 62. GeeksforGeeks. Nano Text Editor in Linux (2024). <br> https://www.geeksforgeeks.org/nano-text-editor-in-linux/
# 63. GeeksforGeeks. How to Make Script Executable in Linux | chmod Command (2024.) <br> https://www.geeksforgeeks.org/chmod-command-linux
# 64. Brown. K. Linuxconfig.org. Understanding chmod: The difference Between u<sup>+x</sup> and <sup>+</sup>x. (2023). <br> https://linuxconfig.org/understanding-chmod-the-difference-between-ux-and-x
# <br>
#
# ##### Task 9
# 65. w3schools. Pandas Introduction. <br> https://www.w3schools.com/python/pandas/pandas_intro.asp
# 66. GeeksforGeeks. Libraries in Python (2024) <br> https://www.geeksforgeeks.org/libraries-in-python/
# 67. DATA.GOV.IE Today's weather Athenry <br> https://data.gov.ie/dataset/todays-weather-athenry
# 68. Wikipedia. Local time (2024). <br> https://en.wikipedia.org/wiki/Local_time#:~:text=Local%20time%20is%20the%20time,time%20where%20and%20when%20applicable.
# 69. Wikipedia. Dry-bulb temperature (2024). <br> https://en.wikipedia.org/wiki/Dry-bulb_temperature
# 70. Wikipedia. Knot (Unit (2024) <br> https://en.wikipedia.org/wiki/Knot_(unit
# 71. Wikipedia. Wind direction (2024) <br> https://en.wikipedia.org/wiki/Wind_direction
# 72. Wikipedia. Humidity. (2024) <br> https://en.wikipedia.org/wiki/Humidity
# 73. Wikipedia. Atmospheric pressure (2024) <br> https://en.wikipedia.org/wiki/Atmospheric_pressure
# 74. DATA.GOV.IE Today's weather Athenry <br> https://data.gov.ie/dataset/todays-weather-athenry
# 75. Open Weather. Weather Icons. (2024) <br> https://openweathermap.org/weather-conditions
# 76. Wikipedia. Comma-separated values. (2024) <br> https://en.wikipedia.org/wiki/Comma-separated_values
# 77. pandas. pandas documentation (2024) <br> https://pandas.pydata.org/docs/
# 78. pandas. pandas DataFrames (2023) <br> https://neuraldatascience.io/3-python/pandas_dataframes.html
# 79. pandas. pandas.DataFrame.shape (2024) <br> https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html
# 80. pandas. pandas.DataFrame.index (2024 <br>) https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.index.html#pandas.DataFrame.index
# 81. Programiz. Pandas Index. <br> https://www.programiz.com/python-programming/pandas/index
# 82. pandas. pandas.DataFrames.dtypes (2024) <br> https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html
# 83. pandas. pandas.DataFrames.dtypes (2024) <br> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html
# 84. Medium. Types of Null Values. (2023) <br> https://medium.com/@_SSP/types-of-null-values-e9e1fa7436e
# 85. Siraj. S Stackoverflow. (2017) <br> https://stackoverflow.com/questions/33957720/how-to-convert-column-with-dtype-as-object-to-string-in-pandas-dataframe
# 86. HYRY. Stackoverflow (2014) <br> https://stackoverflow.com/questions/21018654/strings-in-a-dataframe-but-dtype-is-object
# 87. library carpentry. Data Types and Formats. <br> https://librarycarpentry.github.io/library-python/03-data-types-and-format/#:~:text=A%20type%20%27O%27%20just%20stands,is%20a%20string%20(characters
# 88. pandas. pandas.DataFrame.describe. (2024) <br> https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html
# 89. seaborn. seaborn.histplot. (2024) <br> https://seaborn.pydata.org/generated/seaborn.histplot.html
# 90. seaborn. Matplotlib Subplot. <br> https://www.w3schools.com/python/matplotlib_subplot.asp
# 91. GeeksforGeeks. Seaborn | Style and Color (2021) <br> https://www.geeksforgeeks.org/seaborn-style-and-color/
# 92. Kaggle. Everything you can do with Seaborn. <br> https://www.kaggle.com/code/abhishekmamidi/everything-you-can-do-with-seaborn
# 93. seaborn. seaborn.pairplot (2024) <br> https://seaborn.pydata.org/generated/seaborn.pairplot.html
# 94. GeeksforGeeks. Scatter Diagram Correlation | Meaning, Interpretation, Example (2024). <br> https://www.geeksforgeeks.org/scatter-diagram-correlation-meaning-interpretation-example/
# 95. pandas. pandas.DataFrame.corr (2024). <br> https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html
# 96. Smith. A. pickl. Exploring What is Pandas DataFrame corr() Method? Types and Working (2024) <br> https://www.pickl.ai/blog/exploring-what-is-pandas-dataframe-corr-method-types-and-working/
# <br>
#
# ##### Project
# 97. GitHub Docs. GitHub Actions. About workflows (2024) <br> https://docs.github.com/en/actions/writing-workflows/about-workflows
# 98. GitHub Docs. GitHub Actions. About YAML syntax for workflows. <br> https://docs.github.com/en/actions/writing-workflows/workflow-syntax-for-github-actions#about-yaml-syntax-for-workflows
# 99. GitHub Docs. GitHub Actions. Understanding GitHub Actions <br> https://docs.github.com/en/actions/about-github-actions/understanding-github-actions
# 100. phoenixNAP. How to Create a Directory in Linux via mkdir Command. <br> https://phoenixnap.com/kb/create-directory-linux-mkdir-command
# 101. GeeksforGeeks. How to Change the Directory in Linux | cd Command (2024) <br> https://www.geeksforgeeks.org/cd-command-in-linux-with-examples/
# 102. GeeksforGeeks. How to Create an Empty File in Linux | Touch Command (2024). <br> https://www.geeksforgeeks.org/touch-command-in-linux-with-examples/
# 103. Wikipedia. YAML (2024) <br> https://en.wikipedia.org/wiki/YAML#:~:text=Its%20initial%20name%20was%20intended,oriented%2C%20rather%20than%20document%20markup
# 104. ChatGPT <br> https://chatgpt.com/
# 105. Wikipedia. cron. (2024) <br> https://en.wikipedia.org/wiki/Cron
# 106. crontab guru <br> https://crontab.guru/#0_10_*_*_*
# 107. GitHub Docs. GitHub Actions. Manually running a workflow. (2024) <br> https://docs.github.com/en/actions/
# managing-workflow-runs-and-deployments/managing-workflow-runs/manually-running-a-workflow
# 108. Marketplace. GitHub Action for GitHub Push (2024). <br> https://github.com/marketplace/actions/github-push
# 109. GitHub Docs. GitHub Actions. About GitHub-hosted runners (2024) <br> https://docs.github.com/en/actions/using-github-hosted-runners/using-github-hosted-runners/about-github-hosted-runners
# 110. GitHub Docs. GitHub Actions. Understanding GitHub Actions (2024) <br> https://docs.github.com/en/actions/about-github-actions/understanding-github-actions
# 111. Github / actions / checkout. <br> https://github.com/actions/checkout
# 112. Foster. G Graphite. How to use the checkout action in GitHub Actions (2024). <br> https://graphite.dev/guides/github-actions-checkout
# 113. Bevans Bench. Understanding the Pipe Character | in YAML: Multiline Strings Explained (2024) <br> https://www.bevansbench.com/blog/understanding-pipe-character-yaml-multiline-strings-explained
# 114. GeeksforGeeks. What Does "chmod +x " Do and How to Use It? (2024). <br> https://www.geeksforgeeks.org/what-does-chmod-x-do-and-how-to-use-it/
# 115. phoenixNAP. Linux: Add a Directory to PATH (2022). <br> https://phoenixnap.com/kb/linux-add-to-path#:~:text=PATH%20is%20an%20environment%20variable,to%20remove%20it%20in%20Linux.
# 116. Elofsson. J & Floris. superuser. Why do I need a "./" before executing some scripts? [duplicate] (2013) <br> https://superuser.com/questions/586636/why-do-i-need-a-before-executing-some-scripts
# 117. GitHub Docs. GitHub Actions. Set up Git (2024) <br> https://docs.github.com/en/get-started/getting-started-with-git/set-up-git
# 118. Git Guides (2024) <br> https://github.com/git-guides
# 119. GitHub Docs. GitHub Actions.Automatic token authentication (2024) <br> https://docs.github.com/en/actions/security-for-github-actions/security-guides/automatic-token-authentication
# 120. Kumar. S GitHub Actions Scheduled Workflows: Understanding the Limitations and Possible Solutions (2024) <br> https://www.sivamuthukumar.com/blog/ghactions-scheduled-workflows-external-trigger
# <br>
#
# ##### Markdown References
# - Document 360 (2024) <br> https://docs.document360.com/docs/how-to-change-the-color-of-the-text-in-markdown
# - Markdown Guides. Hacks. (2024) <br> https://www.markdownguide.org/hacks/#:~:text=If%20your%20Markdown%20processor%20supports,these%20words%20will%20be%20underlined%20.
# - Markdown Guide. Basic Syntax (2024) <br> https://www.markdownguide.org/basic-syntax/
# - codecademy Links (2024) <br> https://www.codecademy.com/resources/docs/markdown/links
# - w3schools Markdown Superscript (2024) <br> https://www.w3schools.io/file/markdown-super-sub-script/
# - IBM CLoud Pak for Data. Markdown cheatsheet (2024) <br> https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/markd-jupyter.html?context=cpdaas
# - Squarespace Forum (2022)<br> https://forum.squarespace.com/topic/231281-markdown-center-align-and-change-font-color/
# - Markdown Guide. Extended Syntax (2024) <br> https://www.markdownguide.org/extended-syntax/
# - codecademy. Images (2024 <br>) https://www.codecademy.com/resources/docs/markdown/images
# - hrbrmstr. stackoverflow. (2014) <br> https://stackoverflow.com/questions/26234119/how-can-i-write-a-degree-symbol-in-rmarkdown2-for-html-and-pdf-output
# - Rathbone. M. Markdown Tools How to Change Image Size in Markdown (2024) <br> https://blog.markdowntools.com/posts/markdown-change-image-size

# %% [markdown]
# # **<span style="color:blue">End</span>**
# ***
